# %%
# Import Dependencies
import pandas as pd
import os

# %%
orig_working_directory = os.getcwd()
print(orig_working_directory)
# Out:
# /Users/carlyfabris/Desktop/GIT/Traffic_Project/To_Delete

# %%
Feb_Traffic = pd.read_csv("Moving_Violations_Issued_in_February_2019.csv")

# %%
Traffic_df = pd.DataFrame(Feb_Traffic)

# %%
traffic_V = Traffic_df.groupby(["LOCATION","VIOLATION_CODE"]).count()

# %%
traffic_V.sort_values("TICKET_NUMBER", ascending=False)
# Out:
#                                                     OBJECTID  TICKET_NUMBER  \
# LOCATION                            VIOLATION_CODE
# 600 blk Kenilworth Ave NE s/b       T119                4199           4199
# 3rd St Tunnel NW n/b by MA Ave      T119                3396           3396
# 2200 blk K St NW w/b                T119                2973           2973
# 2200 block K St NW e/b              T119                2548           2548
# DC295 SW .7 miles s/o Exit 1 S/B    T119                2395           2395
# ...                                                      ...            ...
# AT 600 ALABAMA AVE SE               T673                   1              1
# AT 600 H ST NE                      T083                   1              1
# AT 6007 7TH ST SW NORTHBOUND @FRON* T333                   1              1
#                                     T711                   1              1
# BLOCK 1935 18TH ST SE               T404                   1              1
#
# ...

# %%
traffic_fort = Traffic_df.loc[Traffic_df["LOCATION"]== "Fort Lincoln Dr s/b @ 31st Pl NE"]
traffic_fort
# Out:
#       OBJECTID TICKET_NUMBER              ISSUE_DATE ISSUE_TIME  \
# 1396    669589    D024263919  2019/02/11 00:00:00+00   09:51:00
# 1397    669590    D024263927  2019/02/11 00:00:00+00   10:03:00
# 1399    669592    D024263943  2019/02/11 00:00:00+00   10:15:00
# 1400    669593    D024263950  2019/02/11 00:00:00+00   10:21:00
# 1401    669594    D024263968  2019/02/11 00:00:00+00   10:22:00
# ...        ...           ...                     ...        ...
# 8738    685092    D024294116  2019/02/17 00:00:00+00   04:28:00
# 8739    685093    D024294124  2019/02/17 00:00:00+00   04:50:00
# 8740    685094    D024294132  2019/02/17 00:00:00+00   04:51:00
# 8793    685147    D024312085  2019/02/21 00:00:00+00   02:20:00
# 8799    685153    D024312141  2019/02/21 00:00:00+00   03:07:00
#
#       ISSUING_AGENCY_CODE                  ISSUING_AGENCY_NAME  \
# 1396                 25.0  SPECIAL OPERATION DIV & TRAFFIC DIV
# 1397                 25.0  SPECIAL OPERATION DIV & TRAFFIC DIV
# ...
